# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
art = cv2.imread(r"C:\Users\User\Desktop\del\art.jpg")
background = cv2.imread(r"C:\Users\User\Desktop\del\background.jpg")

# %%
art = cv2.resize(art,(200,200))
mask = np.any(art < 250,axis = 2)
plt.imshow(cv2.cvtColor(art, cv2.COLOR_BGR2RGB))
plt.show()

# %%
background.shape
# Out:
# (1773, 2364, 3)

# %%
art.shape
# Out:
# (200, 200, 3)

# %%
roi = background[1200:1400, 1700:1900, :]
roi[mask] = art[mask]

plt.imshow(cv2.cvtColor(background, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cv2.imwrite(r"C:\Users\User\Desktop\del\result.jpg",background)
# Out:
# True
